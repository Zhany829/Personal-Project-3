# %%
import os, requests,json,csv
import numpy as np
import sqlite3
import pandas as pd
from pandas import DataFrame, Series
# %matplotlib inline
import matplotlib
from pandas.io.json import json_normalize
from matplotlib import pyplot as plt
from sqlalchemy import create_engine
import MySQLdb

# %%
def get_all_files():
    res = []
    files = os.listdir()
    for file in files:
        if file[-4:] == '.csv':
            res.append(file)
    return res

# %%
csv_files = get_all_files()
csv_files
# Out:
# ['BBC News-2021.04.28.csv',
#  'BBC News-2021.04.29.csv',
#  'BBC News-2021.05.04.csv',
#  'BBC News-2021.05.05.csv']

# %%
def get_all_data(files):
    res = []
    for file in files:
        cur_file = []
        date = file[9:-4]
        f = open(file)
        reader = csv.DictReader(f)
        for row in reader:
            row.update({'Date':date})
            cur_file.append(row)
        #cur_file.append()
        f.close()
        res.append(cur_file)
    return res

# %%
# Get all row from all files
all_data = get_all_data(csv_files)
all_data
# Out:
# [[{'Title': 'SECTION 1: TOP NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.28'},
#   {'Title': "'A horror story': India Covid deaths pass 200,000",
#    'Tag': 'Asia',
#    'Summary': 'There are fears the real number is even higher, as hospitals continue to turn dying patients away.',
#    'URL': 'https://www.bbc.com/news/world-asia-56919924',
#    'Date': '2021.04.28'},
#   {'Title': 'Man charged over oxygen SOS for dying grandfather',
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56894757',
#    'Date': '2021.04.28'},
#   {'Title': "US investigators raid Rudy Giuliani's home",
#    'Tag': 'US',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56921179',
#    'Date': '2021.04.28'},
#   {'Title': "Why we should fear the 'Stomp Reflex'",
#    'Tag': 'Future',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210427-the-stomp-reflex-when-governments-abuse-emergency-powers',
#    'Date': '2021.04.28'},
#   {'Title': "Oman's spectacular 'Norway of Arabia'",
#    'Tag': 'Travel',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/travel/story/20210427-omans-spectacular-norway-of-arabia',
#    'Date': '2021.04.28'},
#   {'Title': 'SECTION 2: NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.28'},
#   {'Title': 'Apollo 11 astronaut Michael Collins dies at 90',
#    'Tag': 'US & Canada',
#    'Summary': 'Michael Collins stayed in orbit as Neil Armstrong and Buzz Aldrin walked on the Moon in 1969.',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56921562',
#    'Date': '2021.04.28'},
#   {'Title': 'Biden to pitch child care and free university plan',
#    'Tag': 'US & Canada',
#    'Summary': 'The Democrat will pledge to enact free pre-school and community college in a speech to Congress.',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56910884',
#    'Date': '2021.04.28'},
#   {'Title': "A small green rock's warning about our climate future",
#    'Tag': 'Science & Environment',
#    'Summary': 'A cobble from under the sea tells a story of how the West Antarctic Ice Sheet could disappear.',
#    'URL': 'https://www.bbc.com/news/science-environment-56904548',
#    'Date': '2021.04.28'},
#   {'Title': 'Champions League semi-final: PSG v Man City - radio & text',
#    'Tag': 'European Football',
#    'Summary': 'Follow live text and BBC Radio 5 Live commentary as Man City travel to PSG for the first leg of their Champions League semi-final.',
#    'URL': 'https://www.bbc.com/sport/live/football/54074602',
#    'Date': '2021.04.28'},
#   {'Title': 'Marcelo doubt for Real over polling duty',
#    'Tag': 'European Football',
#    'Summary': "Real Madrid's Marcelo may miss their Champions League semi-final second leg at Chelsea because of polling station during local elections.",
#    'URL': 'https://www.bbc.com/sport/football/56915346',
#    'Date': '2021.04.28'},
#   {'Title': 'Chennai beat Hyderabad to top IPL table',
#    'Tag': 'Cricket',
#    'Summary': 'Three-time champions Chennai Super Kings move to the top of the Indian Premier League table with a seven-wicket win against Sunrisers Hyderabad.',
#    'URL': 'https://www.bbc.com/sport/cricket/56921863',
#    'Date': '2021.04.28'},
#   {'Title': 'SECTION 3: REELS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.28'},
#   {'Title': 'US English: Why do Brits hate it so?',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09fv1w9/why-us-english-is-a-history-lesson-for-the-british',
#    'Date': '2021.04.28'},
#   {'Title': 'The Caribbean island that embraces a deadly sin',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09ftqzh/the-paradise-island-with-a-lesson-about-pride',
#    'Date': '2021.04.28'},
#   {'Title': 'The simple thing that instantly changes our social status',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09fr7s2/what-your-clothes-reveal-about-you',
#    'Date': '2021.04.28'},
#   {'Title': 'The underappreciated power of human poo',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-underappreciated-power-of-human-poo',
#    'Date': '2021.04.28'},
#   {'Title': "A neglected protein-rich 'superfood'",
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-protein-rich-superfood-most-europeans-wont-eat',
#    'Date': '2021.04.28'},
#   {'Title': 'The world capital of the dirtiest coal',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210419-the-end-of-the-worlds-capital-of-brown-coal',
#    'Date': '2021.04.28'},
#   {'Title': 'SECTION 4: COLLAPSE IMAGE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.28'},
#   {'Title': "How multitasking spurs a 'brain boost'",
#    'Tag': 'Worklife',
#    'Summary': "Common beliefs about juggling tasks may be wrong – and that's a good thing",
#    'URL': 'https://www.bbc.com/worklife/article/20210416-how-multitasking-fuels-original-thinking',
#    'Date': '2021.04.28'},
#   {'Title': 'Why old TV shows make you feel better',
#    'Tag': 'Culture',
#    'Summary': 'From Seinfeld to The Sopranos, why revisiting favourite series is good for you',
#    'URL': 'https://www.bbc.com/culture/article/20210427-is-rewatching-old-tv-good-for-the-soul',
#    'Date': '2021.04.28'},
#   {'Title': 'A Central Asian alternative to parmesan',
#    'Tag': 'Travel',
#    'Summary': 'This calcium-rich snack accompanied travellers along the Silk Road and beyond',
#    'URL': 'https://www.bbc.com/travel/story/20210426-qurt-a-kazakh-cheese-of-resilience',
#    'Date': '2021.04.28'},
#   {'Title': 'The trees that stall wildlife crime',
#    'Tag': 'Future Planet',
#    'Summary': 'Mangroves have long been known to store carbon, but now they are cutting crime',
#    'URL': 'https://www.bbc.com/future/article/20210423-kenyas-unusual-solution-to-illegal-poaching-and-logging',
#    'Date': '2021.04.28'},
#   {'Title': 'How space inspired Soviet artists',
#    'Tag': 'Future',
#    'Summary': "Space was a broad canvas for the USSR's artists and designers",
#    'URL': 'https://www.bbc.com/future/article/20210426-how-the-space-race-changed-soviet-art',
#    'Date': '2021.04.28'},
#   {'Title': 'Spears asks to address court over conservatorship',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'A judge grants request for the singer to speak in hearing about her long-running guardianship case',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56911822',
#    'Date': '2021.04.28'},
#   {'Title': 'Family-meal image wins international food photo contest',
#    'Tag': 'In Pictures',
#    'Summary': 'Li Huaifeng has been named Pink Lady Food Photographer of the Year 2021',
#    'URL': 'https://www.bbc.com/news/in-pictures-56820167',
#    'Date': '2021.04.28'},
#   {'Title': 'Why crying can help you succeed in business',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56683783',
#    'Date': '2021.04.28'},
#   {'Title': 'What will happen to all the dead car batteries?',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56574779',
#    'Date': '2021.04.28'},
#   {'Title': "Nagra turned down for TV role 'for being Asian'",
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'Bend it Like Beckham and ER actress Parminder Nagra says she was rejected by "a well-known TV show".',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56915260',
#    'Date': '2021.04.28'},
#   {'Title': 'Delegates rub shoulders at mask-free conference',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56915697',
#    'Date': '2021.04.28'},
#   {'Title': 'One Covid vaccine dose halves transmission - study',
#    'Tag': 'Health',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/health-56904993',
#    'Date': '2021.04.28'},
#   {'Title': 'Accident leaves deep sea mining machine stranded',
#    'Tag': 'Science & Environment',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/science-environment-56921773',
#    'Date': '2021.04.28'},
#   {'Title': "Facebook: Smoking and alcohol ads 'target children'",
#    'Tag': 'Technology',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/technology-56920992',
#    'Date': '2021.04.28'},
#   {'Title': 'Covid-19: US relaxes guidance on masks outdoors',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56908373',
#    'Date': '2021.04.28'},
#   {'Title': 'Florence Welch to score Great Gatsby musical',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56915423',
#    'Date': '2021.04.28'},
#   {'Title': 'The salmon you buy in the future may be farmed on land',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56829129',
#    'Date': '2021.04.28'},
#   {'Title': 'The gentle crafts that bring peace',
#    'Tag': 'Culture',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/culture/article/20210421-the-gentle-crafts-that-bring-peace',
#    'Date': '2021.04.28'},
#   {'Title': 'SECTION 5: FEATURED VIDEO',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.28'},
#   {'Title': "'Sister help us, doctor help us - you’re God'",
#    'Tag': 'India',
#    'Summary': "What it's like working in an emergency room in India, as its devastating second Covid wave continues.",
#    'URL': 'https://www.bbc.com/news/world-asia-india-56901163',
#    'Date': '2021.04.28'},
#   {'Title': "'Sister help us, doctor help us - you’re...",
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56901163',
#    'Date': '2021.04.28'},
#   {'Title': "Youngest Mastermind winner: 'It feels like a...",
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56900431',
#    'Date': '2021.04.28'},
#   {'Title': 'British Oscar winners celebrate success',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56886227',
#    'Date': '2021.04.28'},
#   {'Title': "'I lost my unborn child and wife on the same...",
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56908383',
#    'Date': '2021.04.28'},
#   {'Title': 'Indian couple get married in full PPE...',
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56916354',
#    'Date': '2021.04.28'},
#   {'Title': 'Ready for the total solar eclipse?',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40362067',
#    'Date': '2021.04.28'},
#   {'Title': 'Great Mosque of al-Nuri destroyed',
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40369547',
#    'Date': '2021.04.28'},
#   {'Title': "Video 'shows Mosul mosque's destruction'",
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40366136',
#    'Date': '2021.04.28'},
#   {'Title': 'The rise of the female fitness model',
#    'Tag': 'England',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-england-40058866',
#    'Date': '2021.04.28'},
#   {'Title': 'Car burglar caught with his pants down',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40360953',
#    'Date': '2021.04.28'},
#   {'Title': 'The birds on the balcony that found TikTok...',
#    'Tag': 'Australia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-australia-56883027',
#    'Date': '2021.04.28'},
#   {'Title': 'Returning home to a nuclear disaster zone',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56864709',
#    'Date': '2021.04.28'},
#   {'Title': 'One-minute World News',
#    'Tag': 'Video',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/10462520',
#    'Date': '2021.04.28'},
#   {'Title': 'The community that trades by barter',
#    'Tag': 'Africa',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-africa-56892765',
#    'Date': '2021.04.28'},
#   {'Title': "Children of the 90s study: 'I feel...",
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56901164',
#    'Date': '2021.04.28'},
#   {'Title': 'SECTION 6: WORLD IN PICTURE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.28'},
#   {'Title': "India's round-the-clock mass cremations",
#    'Tag': 'In Pictures',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/in-pictures-56913348',
#    'Date': '2021.04.28'},
#   {'Title': 'In pictures: Pink Supermoon around the world',
#    'Tag': 'In Pictures',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/in-pictures-56900164',
#    'Date': '2021.04.28'},
#   {'Title': '13 major looks from the Oscars red carpet',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56864780',
#    'Date': '2021.04.28'},
#   {'Title': 'Search to find girl in docks photo 100 years on',
#    'Tag': 'Wales',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-wales-56843429',
#    'Date': '2021.04.28'},
#   {'Title': "Africa's top shots: Firebreathers and farewells",
#    'Tag': 'Africa',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-africa-56843885',
#    'Date': '2021.04.28'}],
#  [{'Title': 'SECTION 1: TOP NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.29'},
#   {'Title': 'Biden pitches sweeping investment plan to Congress',
#    'Tag': 'US & Canada',
#    'Summary': 'The president lays out jobs, education and social care plans and says "America\'s on the move again".',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56923515',
#    'Date': '2021.04.29'},
#   {'Title': 'China launches first module of new space station',
#    'Tag': 'China',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-china-56924370',
#    'Date': '2021.04.29'},
#   {'Title': "'A horror story': India Covid deaths pass 200,000",
#    'Tag': 'Asia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-56919924',
#    'Date': '2021.04.29'},
#   {'Title': 'Handsets push Samsung profits to pre-pandemic high',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56924158',
#    'Date': '2021.04.29'},
#   {'Title': "Why we're measuring burnout wrong",
#    'Tag': 'Worklife',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/worklife/article/20210426-why-we-may-be-measuring-burnout-all-wrong',
#    'Date': '2021.04.29'},
#   {'Title': 'SECTION 2: NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.29'},
#   {'Title': 'What has Biden done in 100 days?',
#    'Tag': 'US & Canada',
#    'Summary': "The new US president can point to a list of achievements but there's plenty for him to ponder at the 100-day mark.",
#    'URL': 'https://www.bbc.com/news/world-us-canada-56919076',
#    'Date': '2021.04.29'},
#   {'Title': "US investigators raid Rudy Giuliani's home",
#    'Tag': 'US & Canada',
#    'Summary': 'The former New York mayor and lawyer to Donald Trump is being investigated for dealings with Ukraine.',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56921179',
#    'Date': '2021.04.29'},
#   {'Title': 'Deadly Covid wave rips through small-town India',
#    'Tag': 'India',
#    'Summary': 'The virus is spreading to remote corners of India where healthcare is poor and the crisis under-reported.',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56913047',
#    'Date': '2021.04.29'},
#   {'Title': 'Man City fight back to win at PSG',
#    'Tag': 'European Football',
#    'Summary': 'Manchester City score twice in seven minutes to win at Paris St-Germain in the first leg of their Champions League semi-final.',
#    'URL': 'https://www.bbc.com/sport/football/56880443',
#    'Date': '2021.04.29'},
#   {'Title': 'He left his brain behind to save others from his fate',
#    'Tag': 'Sport',
#    'Summary': 'Zac Easter killed himself at the age of 24, having suffered for years from a debilitating disease caused by the sport he loved.',
#    'URL': 'https://www.bbc.co.uk/sport/american-football/56894868',
#    'Date': '2021.04.29'},
#   {'Title': 'Chennai beat Hyderabad to top IPL table',
#    'Tag': 'Cricket',
#    'Summary': 'Three-time champions Chennai Super Kings move to the top of the Indian Premier League table with a seven-wicket win against Sunrisers Hyderabad.',
#    'URL': 'https://www.bbc.com/sport/cricket/56921863',
#    'Date': '2021.04.29'},
#   {'Title': 'SECTION 3: REELS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.29'},
#   {'Title': 'How waiting alters our perception of time',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09cdyyd/how-waiting-alters-our-perception-of-time',
#    'Date': '2021.04.29'},
#   {'Title': 'US English: Why do Brits hate it so?',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09fv1w9/why-us-english-is-a-history-lesson-for-the-british',
#    'Date': '2021.04.29'},
#   {'Title': 'The Caribbean island that embraces a deadly sin',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09ftqzh/the-paradise-island-with-a-lesson-about-pride',
#    'Date': '2021.04.29'},
#   {'Title': 'The trees that stall wildlife crime',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210423-kenyas-unusual-solution-to-illegal-poaching-and-logging',
#    'Date': '2021.04.29'},
#   {'Title': 'The underappreciated power of human poo',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-underappreciated-power-of-human-poo',
#    'Date': '2021.04.29'},
#   {'Title': "A neglected protein-rich 'superfood'",
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-protein-rich-superfood-most-europeans-wont-eat',
#    'Date': '2021.04.29'},
#   {'Title': 'SECTION 4: COLLAPSE IMAGE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.29'},
#   {'Title': 'The mindful craft that is booming',
#    'Tag': 'Designed',
#    'Summary': 'Slow and tactile pottery is the perfect pastime for now, say its many fans',
#    'URL': 'https://www.bbc.com/culture/article/20210428-why-the-slow-mindful-craft-of-pottery-is-booming-worldwide',
#    'Date': '2021.04.29'},
#   {'Title': "Why we should fear the 'Stomp Reflex'",
#    'Tag': 'Future',
#    'Summary': 'The worrying overreach of governments during crises',
#    'URL': 'https://www.bbc.com/future/article/20210427-the-stomp-reflex-when-governments-abuse-emergency-powers',
#    'Date': '2021.04.29'},
#   {'Title': 'The ultimate forbidden fruit? A lemon',
#    'Tag': 'Culture',
#    'Summary': 'How a lemon symbolised the original fall from grace',
#    'URL': 'https://www.bbc.com/culture/article/20210428-the-ghent-altarpiece-an-unlikely-fruit-meaning-original-sin',
#    'Date': '2021.04.29'},
#   {'Title': "The jobs 'crushing' young workers",
#    'Tag': 'Worklife',
#    'Summary': '"There were a lot of sweaty shirts, crying and not knowing what I was doing"',
#    'URL': 'https://www.bbc.com/worklife/article/20210426-is-extreme-working-culture-worth-the-big-rewards',
#    'Date': '2021.04.29'},
#   {'Title': 'A fruit with more caffeine than coffee',
#    'Tag': 'Travel',
#    'Summary': 'It bears a disconcerting resemblance to an eyeball',
#    'URL': 'https://www.bbc.com/travel/story/20210428-guaran-the-edible-eyes-of-the-amazon',
#    'Date': '2021.04.29'},
#   {'Title': "India's round-the-clock mass cremations",
#    'Tag': 'In Pictures',
#    'Summary': 'Some crematoriums have been operating non-stop as a second wave of coronavirus engulfs the country',
#    'URL': 'https://www.bbc.com/news/in-pictures-56913348',
#    'Date': '2021.04.29'},
#   {'Title': 'Back to the office? Best desk locations revealed',
#    'Tag': 'Health',
#    'Summary': 'Where you sit in an open-plan office can determine how content and productive you feel, researchers...',
#    'URL': 'https://www.bbc.com/news/health-56886313',
#    'Date': '2021.04.29'},
#   {'Title': 'Why crying can help you succeed in business',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56683783',
#    'Date': '2021.04.29'},
#   {'Title': 'What will happen to all the dead car batteries?',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56574779',
#    'Date': '2021.04.29'},
#   {'Title': "Nagra turned down for TV role 'for being Asian'",
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'Bend it Like Beckham and ER actress Parminder Nagra says she was rejected by "a well-known TV show".',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56915260',
#    'Date': '2021.04.29'},
#   {'Title': 'Why virtual away days may be here to stay',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.co.uk/news/business-56899633',
#    'Date': '2021.04.29'},
#   {'Title': 'One Covid vaccine dose halves transmission - study',
#    'Tag': 'Health',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/health-56904993',
#    'Date': '2021.04.29'},
#   {'Title': 'Accident leaves deep sea mining machine stranded',
#    'Tag': 'Science & Environment',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/science-environment-56921773',
#    'Date': '2021.04.29'},
#   {'Title': "Facebook: Smoking and alcohol ads 'target children'",
#    'Tag': 'Technology',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/technology-56920992',
#    'Date': '2021.04.29'},
#   {'Title': 'Covid-19: US relaxes guidance on masks outdoors',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56908373',
#    'Date': '2021.04.29'},
#   {'Title': 'Florence Welch to score Great Gatsby musical',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56915423',
#    'Date': '2021.04.29'},
#   {'Title': 'The salmon you buy in the future may be farmed on land',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56829129',
#    'Date': '2021.04.29'},
#   {'Title': 'The gentle crafts that bring peace',
#    'Tag': 'Culture',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/culture/article/20210421-the-gentle-crafts-that-bring-peace',
#    'Date': '2021.04.29'},
#   {'Title': 'SECTION 5: FEATURED VIDEO',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.29'},
#   {'Title': 'Sikh temple offers drive-through oxygen to Covid patients',
#    'Tag': 'Asia',
#    'Summary': 'More than 1,000 people have used the service being offered by one Gurdwara in Uttar Pradesh.',
#    'URL': 'https://www.bbc.com/news/world-asia-56922494',
#    'Date': '2021.04.29'},
#   {'Title': 'Sikh temple offers drive-through oxygen to...',
#    'Tag': 'Asia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-56922494',
#    'Date': '2021.04.29'},
#   {'Title': "Youngest Mastermind winner: 'It feels like a...",
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56900431',
#    'Date': '2021.04.29'},
#   {'Title': 'British Oscar winners celebrate success',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56886227',
#    'Date': '2021.04.29'},
#   {'Title': "'Sister help us, doctor help us - you’re...",
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56901163',
#    'Date': '2021.04.29'},
#   {'Title': "'I lost my unborn child and wife on the same...",
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56908383',
#    'Date': '2021.04.29'},
#   {'Title': 'Ready for the total solar eclipse?',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40362067',
#    'Date': '2021.04.29'},
#   {'Title': 'Great Mosque of al-Nuri destroyed',
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40369547',
#    'Date': '2021.04.29'},
#   {'Title': "Video 'shows Mosul mosque's destruction'",
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40366136',
#    'Date': '2021.04.29'},
#   {'Title': 'The rise of the female fitness model',
#    'Tag': 'England',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-england-40058866',
#    'Date': '2021.04.29'},
#   {'Title': 'Car burglar caught with his pants down',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40360953',
#    'Date': '2021.04.29'},
#   {'Title': "Why a US photographer says 'sorry for the...",
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56859337',
#    'Date': '2021.04.29'},
#   {'Title': 'The birds on the balcony that found TikTok...',
#    'Tag': 'Australia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-australia-56883027',
#    'Date': '2021.04.29'},
#   {'Title': 'Returning home to a nuclear disaster zone',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56864709',
#    'Date': '2021.04.29'},
#   {'Title': 'One-minute World News',
#    'Tag': 'Video',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/10462520',
#    'Date': '2021.04.29'},
#   {'Title': 'The community that trades by barter',
#    'Tag': 'Africa',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-africa-56892765',
#    'Date': '2021.04.29'},
#   {'Title': 'SECTION 6: WORLD IN PICTURE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.04.29'},
#   {'Title': 'Family meal wins international food photo contest',
#    'Tag': 'In Pictures',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/in-pictures-56820167',
#    'Date': '2021.04.29'},
#   {'Title': 'In pictures: Pink Supermoon around the world',
#    'Tag': 'In Pictures',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/in-pictures-56900164',
#    'Date': '2021.04.29'},
#   {'Title': '13 major looks from the Oscars red carpet',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56864780',
#    'Date': '2021.04.29'},
#   {'Title': 'Search to find girl in docks photo 100 years on',
#    'Tag': 'Wales',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-wales-56843429',
#    'Date': '2021.04.29'},
#   {'Title': "Africa's top shots: Firebreathers and farewells",
#    'Tag': 'Africa',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-africa-56843885',
#    'Date': '2021.04.29'}],
#  [{'Title': 'SECTION 1: TOP NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.04'},
#   {'Title': 'Mexico City metro overpass collapse kills 23',
#    'Tag': 'Latin America & Caribbean',
#    'Summary': 'Two train carriages plunged to the ground when an elevated metro line collapsed.',
#    'URL': 'https://www.bbc.com/news/world-latin-america-56977129',
#    'Date': '2021.05.04'},
#   {'Title': 'Mourinho named Roma boss from next season',
#    'Tag': 'European Football',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/sport/football/56983649',
#    'Date': '2021.05.04'},
#   {'Title': 'Belgian farmer accidentally moves French border',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56978344',
#    'Date': '2021.05.04'},
#   {'Title': 'The untapped power of Patagonian berries',
#    'Tag': 'Travel',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/travel/story/20210503-the-untapped-power-of-patagonian-berries',
#    'Date': '2021.05.04'},
#   {'Title': 'How looking young can shape your career',
#    'Tag': 'Worklife',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/worklife/article/20210503-how-looking-young-can-shape-your-career',
#    'Date': '2021.05.04'},
#   {'Title': 'SECTION 2: NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.04'},
#   {'Title': 'Calls grow for national lockdown in India',
#    'Tag': 'India',
#    'Summary': 'As infections pass 20 million, the government says cases are "slowing down" and resists lockdown.',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56976214',
#    'Date': '2021.05.04'},
#   {'Title': 'Cautious hopes for overseas summer holidays',
#    'Tag': 'UK',
#    'Summary': 'EU leaders will discuss rules for travel while UK ministers say an announcement will come "shortly".',
#    'URL': 'https://www.bbc.com/news/live/uk-56977099',
#    'Date': '2021.05.04'},
#   {'Title': 'The Americans hesitant about the Covid vaccine',
#    'Tag': 'US & Canada',
#    'Summary': 'For the US to achieve herd immunity it needs to convince two big groups to get the jab.',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56929695',
#    'Date': '2021.05.04'},
#   {'Title': 'IPL suspended after more Covid-19 cases',
#    'Tag': 'Cricket',
#    'Summary': 'The Indian Premier League is suspended after an increase in coronavirus cases among players.',
#    'URL': 'https://www.bbc.com/sport/cricket/56978321',
#    'Date': '2021.05.04'},
#   {'Title': 'PSG face anxious wait over Mbappe fitness',
#    'Tag': 'European Football',
#    'Summary': "Paris St-Germain face an anxious wait to see if Kylian Mbappe will be fit to face Manchester City in Tuesday's Champions League semi-final second leg.",
#    'URL': 'https://www.bbc.com/sport/football/56973031',
#    'Date': '2021.05.04'},
#   {'Title': "Murder-accused PC 'kicked' and Tasered footballer",
#    'Tag': 'Shropshire',
#    'Summary': 'Dalian Atkinson was Tasered for six times longer than standard by PC Benjamin Monk, a court is told.',
#    'URL': 'https://www.bbc.com/news/uk-england-shropshire-56979521',
#    'Date': '2021.05.04'},
#   {'Title': 'SECTION 3: REELS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.04'},
#   {'Title': "The forgotten wonder material that 'can withstand 75 nuclear blasts'",
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09g0qfv/the-wonder-material-that-protects-against-nuclear-blasts-',
#    'Date': '2021.05.04'},
#   {'Title': 'The Caribbean island that embraces a deadly sin',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09ftqzh/the-paradise-island-with-a-lesson-about-pride',
#    'Date': '2021.05.04'},
#   {'Title': 'Surprising images from inside North Korea',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p081rqqq/surprising-images-from-inside-north-korea',
#    'Date': '2021.05.04'},
#   {'Title': 'The trees that stall wildlife crime',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210423-kenyas-unusual-solution-to-illegal-poaching-and-logging',
#    'Date': '2021.05.04'},
#   {'Title': 'The underappreciated power of human poo',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-underappreciated-power-of-human-poo',
#    'Date': '2021.05.04'},
#   {'Title': "A neglected protein-rich 'superfood'",
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-protein-rich-superfood-most-europeans-wont-eat',
#    'Date': '2021.05.04'},
#   {'Title': 'SECTION 4: COLLAPSE IMAGE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.04'},
#   {'Title': 'The anti-Marie Kondo trend for clutter',
#    'Tag': 'Culture',
#    'Summary': 'British PM Boris Johnson and his fiancée are among the many fans of maximalism',
#    'URL': 'https://www.bbc.com/culture/article/20210430-cluttercore-the-joy-of-a-maximalist-home',
#    'Date': '2021.05.04'},
#   {'Title': "Why we can't treat Covid-19 with drugs",
#    'Tag': 'Future',
#    'Summary': 'Scientists searching for drug-based treatments have their work cut out',
#    'URL': 'https://www.bbc.com/future/article/20210430-why-arent-antiviral-drugs-as-effective-as-antibiotics',
#    'Date': '2021.05.04'},
#   {'Title': "How the busiest people do 'deep work'",
#    'Tag': 'Worklife',
#    'Summary': 'The simple hacks that create space for the most meaningful and productive work',
#    'URL': 'https://www.bbc.com/worklife/article/20210429-how-the-busiest-people-get-deep-work-done',
#    'Date': '2021.05.04'},
#   {'Title': "A mysterious 'portal' to the Universe",
#    'Tag': 'Travel',
#    'Summary': 'The map has puzzled archaeologists and academics for more than a century',
#    'URL': 'https://www.bbc.com/travel/story/20210502-the-unsolved-mystery-of-sri-lankas-stargate',
#    'Date': '2021.05.04'},
#   {'Title': "The rise of India's 'Covid quack'",
#    'Tag': 'BBC Trending',
#    'Summary': 'An anti-vax campaigner falsely claims to be able to cure Covid-19, diabetes and Aids through diet',
#    'URL': 'https://www.bbc.com/news/blogs-trending-56845610',
#    'Date': '2021.05.04'},
#   {'Title': 'Shark attack survivor wins tooth shark left behind',
#    'Tag': 'Australia',
#    'Summary': 'Surfer Chris Bowes lost his leg but authorities return a tooth the shark left wedged in his board',
#    'URL': 'https://www.bbc.com/news/world-australia-56979429',
#    'Date': '2021.05.04'},
#   {'Title': "Does Scotland's future lie in or out of the Union?",
#    'Tag': 'Scotland',
#    'Summary': 'Views from those both for and against another referendum on independence',
#    'URL': 'https://www.bbc.com/news/uk-scotland-56970549',
#    'Date': '2021.05.04'},
#   {'Title': 'Food giants respond to worries over packaging',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56770732',
#    'Date': '2021.05.04'},
#   {'Title': 'The foods that reverse climate change',
#    'Tag': 'Future',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/bespoke/follow-the-food/the-foods-that-reverse-climate-change/',
#    'Date': '2021.05.04'},
#   {'Title': 'Japan town uses Covid grant to build squid statue',
#    'Tag': 'Asia',
#    'Summary': 'Noto, which is known for its flying squid, hopes the giant statue will draw back tourists',
#    'URL': 'https://www.bbc.com/news/world-europe-56978075',
#    'Date': '2021.05.04'},
#   {'Title': 'New climate promises will mean rise of 2.4C - study',
#    'Tag': 'Science & Environment',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/science-environment-56984691',
#    'Date': '2021.05.04'},
#   {'Title': "Britney Spears slams 'hypocritical' documentaries",
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56979791',
#    'Date': '2021.05.04'},
#   {'Title': 'Warren Buffett names Berkshire Hathaway successor',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56976063',
#    'Date': '2021.05.04'},
#   {'Title': 'EU unveils plans for overseas tourists to return',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56970398',
#    'Date': '2021.05.04'},
#   {'Title': 'Teens, tech and mental health: Study finds no link',
#    'Tag': 'Technology',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/technology-56970368',
#    'Date': '2021.05.04'},
#   {'Title': 'UK sending 1,000 more ventilators to India',
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56965932',
#    'Date': '2021.05.04'},
#   {'Title': "'More and more people don't want a traditional burial'",
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56926819',
#    'Date': '2021.05.04'},
#   {'Title': 'Putin: The street kid who became president',
#    'Tag': 'Now Showing',
#    'Summary': 'None',
#    'URL': 'https://www.bbcselect.com/putin-from-street-kid-to-spy-to-president/?utm_source=BBC%20Homepage&utm_medium=Module&utm_campaign=Putin&utm_content=Street%20Kid',
#    'Date': '2021.05.04'},
#   {'Title': 'SECTION 5: FEATURED VIDEO',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.04'},
#   {'Title': 'Carriages crumpled as Mexico overpass collapses',
#    'Tag': 'Latin America & Caribbean',
#    'Summary': 'A metro overpass partially collapses in Mexico City leaving at least 23 people dead.',
#    'URL': 'https://www.bbc.com/news/world-latin-america-56977421',
#    'Date': '2021.05.04'},
#   {'Title': 'Carriages crumpled as Mexico overpass...',
#    'Tag': 'Latin America & Caribbean',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-latin-america-56977421',
#    'Date': '2021.05.04'},
#   {'Title': '‘No daylight, no watches for 40 days in a...',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56970082',
#    'Date': '2021.05.04'},
#   {'Title': 'Night-time splashdown for four ISS astronauts',
#    'Tag': 'World',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-56962932',
#    'Date': '2021.05.04'},
#   {'Title': 'Royal Marines test out jet suit',
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56979994',
#    'Date': '2021.05.04'},
#   {'Title': 'How rising sea levels are threatening my home',
#    'Tag': 'Asia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-56853156',
#    'Date': '2021.05.04'},
#   {'Title': 'Ready for the total solar eclipse?',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40362067',
#    'Date': '2021.05.04'},
#   {'Title': 'Great Mosque of al-Nuri destroyed',
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40369547',
#    'Date': '2021.05.04'},
#   {'Title': "Video 'shows Mosul mosque's destruction'",
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40366136',
#    'Date': '2021.05.04'},
#   {'Title': 'The rise of the female fitness model',
#    'Tag': 'England',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-england-40058866',
#    'Date': '2021.05.04'},
#   {'Title': 'Car burglar caught with his pants down',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40360953',
#    'Date': '2021.05.04'},
#   {'Title': "River Thames rescue: 'The last time I saw...",
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56974260',
#    'Date': '2021.05.04'},
#   {'Title': "They shouted 'you are the Chinese virus'",
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56937299',
#    'Date': '2021.05.04'},
#   {'Title': "'Yedidya, to my great sorrow, did not...",
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-56967559',
#    'Date': '2021.05.04'},
#   {'Title': 'Vaccinating the Amazon',
#    'Tag': 'Latin America & Caribbean',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-latin-america-56949409',
#    'Date': '2021.05.04'},
#   {'Title': 'SECTION 6: WORLD IN PICTURE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.04'},
#   {'Title': "Why is this the 'most instagrammable' bird?",
#    'Tag': 'Science & Environment',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/science-environment-56946165',
#    'Date': '2021.05.04'},
#   {'Title': "England's seaside heritage from the air",
#    'Tag': 'In Pictures',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/in-pictures-56929622',
#    'Date': '2021.05.04'},
#   {'Title': "Africa's top shots: Palms, patrols and pardons",
#    'Tag': 'Africa',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-africa-56928521',
#    'Date': '2021.05.04'},
#   {'Title': "Kate and William's decade of marriage in pictures",
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56900811',
#    'Date': '2021.05.04'},
#   {'Title': "India's round-the-clock mass cremations",
#    'Tag': 'In Pictures',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/in-pictures-56913348',
#    'Date': '2021.05.04'}],
#  [{'Title': 'SECTION 1: TOP NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.05'},
#   {'Title': "India is a Covid disaster - it didn't have to be",
#    'Tag': 'India',
#    'Summary': "Experts tell the BBC that delays in decision-making worsened the crisis of India's second wave.",
#    'URL': 'https://www.bbc.com/news/world-asia-india-56977653',
#    'Date': '2021.05.05'},
#   {'Title': "Facebook ordered to rethink Trump's permanent ban",
#    'Tag': 'Technology',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/technology-56985583',
#    'Date': '2021.05.05'},
#   {'Title': 'The company where colleagues decide your salary',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56915767',
#    'Date': '2021.05.05'},
#   {'Title': "A new 'slow highway' uniting Britain",
#    'Tag': 'Travel',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/travel/story/20210504-the-plan-to-connect-every-british-town',
#    'Date': '2021.05.05'},
#   {'Title': "A misunderstood icon of 'Scottishness'",
#    'Tag': 'Culture',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/culture/article/20210504-tartan-the-misunderstood-icon-of-scottishness',
#    'Date': '2021.05.05'},
#   {'Title': 'SECTION 2: NEWS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.05'},
#   {'Title': 'George Floyd killer asks for new trial',
#    'Tag': 'US & Canada',
#    'Summary': 'The white former police officer was found guilty of the murder and manslaughter of George Floyd.',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56989757',
#    'Date': '2021.05.05'},
#   {'Title': 'Then and now: Restoring coral reefs in Indonesia',
#    'Tag': 'Science & Environment',
#    'Summary': 'Around 40,000 sq m of coral reef has been restored in Indonesia with plans to extend the scheme further.',
#    'URL': 'https://www.bbc.com/news/science-environment-56985594',
#    'Date': '2021.05.05'},
#   {'Title': 'Mysterious brain disease in Canada baffles doctors',
#    'Tag': 'US & Canada',
#    'Summary': 'Dozens of people in New Brunswick are showing symptoms of the devastating new condition.',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56910393',
#    'Date': '2021.05.05'},
#   {'Title': 'Why Roma will be a job like no other for Mourinho',
#    'Tag': 'European Football',
#    'Summary': 'For the first time in his career Jose Mourinho will not be expected to deliver trophies in the short term, so what can he expect at Roma?',
#    'URL': 'https://www.bbc.com/sport/football/56985925',
#    'Date': '2021.05.05'},
#   {'Title': "'Protests must be civilised' - Solskjaer",
#    'Tag': 'Football',
#    'Summary': 'Manchester United boss Ole Gunnar Solskjaer says protests must be "civilised" after Sunday\'s match against Liverpool was postponed.',
#    'URL': 'https://www.bbc.com/sport/football/57000062',
#    'Date': '2021.05.05'},
#   {'Title': 'Lucky or legendary? Does Zidane get the credit he deserves?',
#    'Tag': 'European Football',
#    'Summary': 'BBC Sport examines why a manager who has claimed almost every trophy available to him is yet to win universal respect.',
#    'URL': 'https://www.bbc.com/sport/football/56918954',
#    'Date': '2021.05.05'},
#   {'Title': 'SECTION 3: REELS',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.05'},
#   {'Title': "Why your cat is both 'dead and alive', according to physics",
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09fgqll/how-can-we-truly-understand-what-s-real-',
#    'Date': '2021.05.05'},
#   {'Title': "The forgotten wonder material that 'can withstand 75 nuclear blasts'",
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p09g0qfv/the-wonder-material-that-protects-against-nuclear-blasts-',
#    'Date': '2021.05.05'},
#   {'Title': 'Surprising images from inside North Korea',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/reel/video/p081rqqq/surprising-images-from-inside-north-korea',
#    'Date': '2021.05.05'},
#   {'Title': 'The trees that stall wildlife crime',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210423-kenyas-unusual-solution-to-illegal-poaching-and-logging',
#    'Date': '2021.05.05'},
#   {'Title': 'The underappreciated power of human poo',
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-underappreciated-power-of-human-poo',
#    'Date': '2021.05.05'},
#   {'Title': "A neglected protein-rich 'superfood'",
#    'Tag': 'None',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210420-the-protein-rich-superfood-most-europeans-wont-eat',
#    'Date': '2021.05.05'},
#   {'Title': 'SECTION 4: COLLAPSE IMAGE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.05'},
#   {'Title': 'The destroyed reef where life now thrives',
#    'Tag': 'Future Planet',
#    'Summary': 'Against the odds, a coral reef in Belize has been brought back to life',
#    'URL': 'https://www.bbc.com/future/article/20210430-the-woman-who-rescues-caribbean-coral',
#    'Date': '2021.05.05'},
#   {'Title': 'How you unknowingly reject great ideas',
#    'Tag': 'Worklife',
#    'Summary': 'Why we tend to gloss over our best ideas – and invest in bad ones',
#    'URL': 'https://www.bbc.com/worklife/article/20210430-why-we-gloss-over-great-ideas-and-invest-in-bad-ones',
#    'Date': '2021.05.05'},
#   {'Title': 'A fruit more powerful than acaí',
#    'Tag': 'Travel',
#    'Summary': 'The rest of the world is finally starting to catch on',
#    'URL': 'https://www.bbc.com/travel/story/20210503-the-untapped-power-of-patagonian-berries',
#    'Date': '2021.05.05'},
#   {'Title': "Amazon's greatest ever series?",
#    'Tag': 'Culture',
#    'Summary': 'Our five star review of remarkable American epic The Underground Railroad',
#    'URL': 'https://www.bbc.com/culture/article/20210504-the-underground-railroad-review-a-remarkable-american-epic',
#    'Date': '2021.05.05'},
#   {'Title': "Why we can't treat Covid-19 with drugs",
#    'Tag': 'Future',
#    'Summary': 'Scientists searching for drug-based treatments have their work cut out',
#    'URL': 'https://www.bbc.com/future/article/20210430-why-arent-antiviral-drugs-as-effective-as-antibiotics',
#    'Date': '2021.05.05'},
#   {'Title': 'Jesy Nelson opens up about quitting Little Mix',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'The star felt "miserable" being compared to her bandmates',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56992706',
#    'Date': '2021.05.05'},
#   {'Title': 'Stratospheric price sought for space-matured wine',
#    'Tag': 'Europe',
#    'Summary': "Christie's predicts the bottle of Pétrus 2000 that orbited the earth could sell for $1m (£720,000)",
#    'URL': 'https://www.bbc.com/news/world-europe-56992086',
#    'Date': '2021.05.05'},
#   {'Title': 'Food giants respond to worries over packaging',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56770732',
#    'Date': '2021.05.05'},
#   {'Title': 'The foods that reverse climate change',
#    'Tag': 'Future',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/bespoke/follow-the-food/the-foods-that-reverse-climate-change/',
#    'Date': '2021.05.05'},
#   {'Title': 'Malian woman gives birth to nine babies',
#    'Tag': 'Africa',
#    'Summary': 'Nonuplets are extremely rare - and doctors had thought Halima Cisse was carrying seven babies',
#    'URL': 'https://www.bbc.com/news/world-africa-56994408',
#    'Date': '2021.05.05'},
#   {'Title': 'Model and singer Nick Kamen dies aged 59',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56991728',
#    'Date': '2021.05.05'},
#   {'Title': "Ancient child grave was Africa's earliest funeral",
#    'Tag': 'Science & Environment',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/science-environment-56986457',
#    'Date': '2021.05.05'},
#   {'Title': 'India opposition calls for full national lockdown',
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56976214',
#    'Date': '2021.05.05'},
#   {'Title': "Peloton recalls treadmills after child's death",
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56993894',
#    'Date': '2021.05.05'},
#   {'Title': 'EU unveils plans for overseas tourists to return',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56970398',
#    'Date': '2021.05.05'},
#   {'Title': 'Oscar winners to be offered fast track UK visas',
#    'Tag': 'Entertainment & Arts',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/entertainment-arts-56991724',
#    'Date': '2021.05.05'},
#   {'Title': "'More and more people don't want a traditional burial'",
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56926819',
#    'Date': '2021.05.05'},
#   {'Title': 'Putin: The street kid who became president',
#    'Tag': 'Now Showing',
#    'Summary': 'None',
#    'URL': 'https://www.bbcselect.com/putin-from-street-kid-to-spy-to-president/?utm_source=BBC%20Homepage&utm_medium=Module&utm_campaign=Putin&utm_content=Street%20Kid',
#    'Date': '2021.05.05'},
#   {'Title': 'SECTION 5: FEATURED VIDEO',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.05'},
#   {'Title': 'Romain Grosjean on life after his career-ending crash',
#    'Tag': 'Formula 1',
#    'Summary': 'F1 driver Romain Grosjean made a remarkable escape from a flaming car last year.',
#    'URL': 'https://www.bbc.com/sport/av/formula1/56995622',
#    'Date': '2021.05.05'},
#   {'Title': 'Romain Grosjean on life after his...',
#    'Tag': 'Formula 1',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/sport/av/formula1/56995622',
#    'Date': '2021.05.05'},
#   {'Title': '‘No daylight, no watches for 40 days in a...',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56970082',
#    'Date': '2021.05.05'},
#   {'Title': 'Night-time splashdown for four ISS astronauts',
#    'Tag': 'World',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-56962932',
#    'Date': '2021.05.05'},
#   {'Title': 'Atlantic row ‘the hardest thing I’ve ever...',
#    'Tag': 'Northern Ireland',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-northern-ireland-56929679',
#    'Date': '2021.05.05'},
#   {'Title': "The newborn calf that 'crashed our wedding'",
#    'Tag': 'Australia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-australia-56976291',
#    'Date': '2021.05.05'},
#   {'Title': 'Ready for the total solar eclipse?',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40362067',
#    'Date': '2021.05.05'},
#   {'Title': 'Great Mosque of al-Nuri destroyed',
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40369547',
#    'Date': '2021.05.05'},
#   {'Title': "Video 'shows Mosul mosque's destruction'",
#    'Tag': 'Middle East',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-middle-east-40366136',
#    'Date': '2021.05.05'},
#   {'Title': 'The rise of the female fitness model',
#    'Tag': 'England',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-england-40058866',
#    'Date': '2021.05.05'},
#   {'Title': 'Car burglar caught with his pants down',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-40360953',
#    'Date': '2021.05.05'},
#   {'Title': 'Carriages crumpled as Mexico overpass...',
#    'Tag': 'Latin America & Caribbean',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-latin-america-56977421',
#    'Date': '2021.05.05'},
#   {'Title': 'Royal Marines test out jet suit',
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56979994',
#    'Date': '2021.05.05'},
#   {'Title': 'One-minute World News',
#    'Tag': 'Video',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/10462520',
#    'Date': '2021.05.05'},
#   {'Title': 'The Americans hesitant about the Covid...',
#    'Tag': 'US & Canada',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56929695',
#    'Date': '2021.05.05'},
#   {'Title': 'How rising sea levels are threatening my home',
#    'Tag': 'Asia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-56853156',
#    'Date': '2021.05.05'},
#   {'Title': 'SECTION 6: WORLD IN PICTURE',
#    'Tag': None,
#    'Summary': None,
#    'URL': None,
#    'Date': '2021.05.05'},
#   {'Title': "Why is this the 'most instagrammable' bird?",
#    'Tag': 'Science & Environment',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/science-environment-56946165',
#    'Date': '2021.05.05'},
#   {'Title': 'In pictures: Shock, grief, anger in Mexico over metro crash',
#    'Tag': 'Latin America & Caribbean',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-latin-america-56989759',
#    'Date': '2021.05.05'},
#   {'Title': "England's seaside heritage from the air",
#    'Tag': 'In Pictures',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/in-pictures-56929622',
#    'Date': '2021.05.05'},
#   {'Title': "Africa's top shots: Palms, patrols and pardons",
#    'Tag': 'Africa',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-africa-56928521',
#    'Date': '2021.05.05'},
#   {'Title': "Kate and William's decade of marriage in pictures",
#    'Tag': 'UK',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/uk-56900811',
#    'Date': '2021.05.05'}]]

# %%
# def get_section_data(section_num):
#     res = {}
#     flag = 0
#     idx = 0
#     for ele in all_data:
#         for row in ele:
#             if  'SECTION ' + str(section_num) in row['Title']:
#                 flag = 1
#             if 'SECTION ' + str(section_num+1) in row['Title']:
#                 flag = 0
#             if section_num == 6 and 'SECTION ' + str(1) in row['Title']:
#                 flag = 0
#             if flag == 1 and 'SECTION ' + str(section_num) not in row['Title']:
#                 row.update({'Index':idx})
#                 res.update({idx:row})
#                 idx+=1
#     return res
def get_section_data(section_num):
    res = []
    flag = 0
    idx = 0
    for ele in all_data:
        for row in ele:
            if  'SECTION ' + str(section_num) in row['Title']:
                flag = 1
            if 'SECTION ' + str(section_num+1) in row['Title']:
                flag = 0
            if section_num == 6 and 'SECTION ' + str(1) in row['Title']:
                flag = 0
            if flag == 1 and 'SECTION ' + str(section_num) not in row['Title']:
                row.update({'Index':idx})
                res.append(row)
#                 print(res)
                idx+=1
    ret = {}
    ret.update({"data":res})
    return ret

# %%
# Get data for each section from all files
sections = []
for i in range(1,7):
    sec = 'section'+str(i)
    sec = get_section_data(i)
    for ele in sec['data']:
        ele['Title'] = ele['Title'].replace('\'', '')
        ele['Summary'] = ele['Summary'].replace('\'', '')
    sections.append(sec)
sections[0]
# Out:
# {'data': [{'Title': 'A horror story: India Covid deaths pass 200,000',
#    'Tag': 'Asia',
#    'Summary': 'There are fears the real number is even higher, as hospitals continue to turn dying patients away.',
#    'URL': 'https://www.bbc.com/news/world-asia-56919924',
#    'Date': '2021.04.28',
#    'Index': 0},
#   {'Title': 'Man charged over oxygen SOS for dying grandfather',
#    'Tag': 'India',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56894757',
#    'Date': '2021.04.28',
#    'Index': 1},
#   {'Title': 'US investigators raid Rudy Giulianis home',
#    'Tag': 'US',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56921179',
#    'Date': '2021.04.28',
#    'Index': 2},
#   {'Title': 'Why we should fear the Stomp Reflex',
#    'Tag': 'Future',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/future/article/20210427-the-stomp-reflex-when-governments-abuse-emergency-powers',
#    'Date': '2021.04.28',
#    'Index': 3},
#   {'Title': 'Omans spectacular Norway of Arabia',
#    'Tag': 'Travel',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/travel/story/20210427-omans-spectacular-norway-of-arabia',
#    'Date': '2021.04.28',
#    'Index': 4},
#   {'Title': 'Biden pitches sweeping investment plan to Congress',
#    'Tag': 'US & Canada',
#    'Summary': 'The president lays out jobs, education and social care plans and says "Americas on the move again".',
#    'URL': 'https://www.bbc.com/news/world-us-canada-56923515',
#    'Date': '2021.04.29',
#    'Index': 5},
#   {'Title': 'China launches first module of new space station',
#    'Tag': 'China',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-china-56924370',
#    'Date': '2021.04.29',
#    'Index': 6},
#   {'Title': 'A horror story: India Covid deaths pass 200,000',
#    'Tag': 'Asia',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-asia-56919924',
#    'Date': '2021.04.29',
#    'Index': 7},
#   {'Title': 'Handsets push Samsung profits to pre-pandemic high',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56924158',
#    'Date': '2021.04.29',
#    'Index': 8},
#   {'Title': 'Why were measuring burnout wrong',
#    'Tag': 'Worklife',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/worklife/article/20210426-why-we-may-be-measuring-burnout-all-wrong',
#    'Date': '2021.04.29',
#    'Index': 9},
#   {'Title': 'Mexico City metro overpass collapse kills 23',
#    'Tag': 'Latin America & Caribbean',
#    'Summary': 'Two train carriages plunged to the ground when an elevated metro line collapsed.',
#    'URL': 'https://www.bbc.com/news/world-latin-america-56977129',
#    'Date': '2021.05.04',
#    'Index': 10},
#   {'Title': 'Mourinho named Roma boss from next season',
#    'Tag': 'European Football',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/sport/football/56983649',
#    'Date': '2021.05.04',
#    'Index': 11},
#   {'Title': 'Belgian farmer accidentally moves French border',
#    'Tag': 'Europe',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/world-europe-56978344',
#    'Date': '2021.05.04',
#    'Index': 12},
#   {'Title': 'The untapped power of Patagonian berries',
#    'Tag': 'Travel',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/travel/story/20210503-the-untapped-power-of-patagonian-berries',
#    'Date': '2021.05.04',
#    'Index': 13},
#   {'Title': 'How looking young can shape your career',
#    'Tag': 'Worklife',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/worklife/article/20210503-how-looking-young-can-shape-your-career',
#    'Date': '2021.05.04',
#    'Index': 14},
#   {'Title': 'India is a Covid disaster - it didnt have to be',
#    'Tag': 'India',
#    'Summary': 'Experts tell the BBC that delays in decision-making worsened the crisis of Indias second wave.',
#    'URL': 'https://www.bbc.com/news/world-asia-india-56977653',
#    'Date': '2021.05.05',
#    'Index': 15},
#   {'Title': 'Facebook ordered to rethink Trumps permanent ban',
#    'Tag': 'Technology',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/technology-56985583',
#    'Date': '2021.05.05',
#    'Index': 16},
#   {'Title': 'The company where colleagues decide your salary',
#    'Tag': 'Business',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/news/business-56915767',
#    'Date': '2021.05.05',
#    'Index': 17},
#   {'Title': 'A new slow highway uniting Britain',
#    'Tag': 'Travel',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/travel/story/20210504-the-plan-to-connect-every-british-town',
#    'Date': '2021.05.05',
#    'Index': 18},
#   {'Title': 'A misunderstood icon of Scottishness',
#    'Tag': 'Culture',
#    'Summary': 'None',
#    'URL': 'https://www.bbc.com/culture/article/20210504-tartan-the-misunderstood-icon-of-scottishness',
#    'Date': '2021.05.05',
#    'Index': 19}]}

# %%
def make_json_file(filename, data):
    if os.path.exists(filename):
        return (str(filename) + " already exists!")     
    json_str = json.dumps(data)
    f = open(filename, "w", encoding="utf-8")
    f.write(json_str)
    f.close()
    return (str(filename) + " created!")

# %%
# make json file for each section data
for i in range(1,7):
    filename = 'section'+str(i)+'.json'
    make_json_file(filename, sections[i-1])

# %%
def get_json_files():
    res = []
    files = os.listdir()
    for file in files:
        if file[-5:] == '.json':
            res.append(file)
    return res

# %%
json_files = get_json_files()

# %%
conn = sqlite3.connect("BBC_NEWS.db")
c = conn.cursor()

# %%
for i in range(1,7):
    table_name = 'SECTION' + str(i)
    file_name = 'section'+str(i)+'.json'
    conn.execute('''CREATE TABLE %s'''%(table_name)+'''
      (IDX      TEXT   NULL,
       DATE            TEXT      NULL,
       TITLE           VARCHAR(500)      NULL,
       TAG             TEXT    NOT   NULL,
       SUMMARY         VARCHAR(500)      NULL,
       URL             TEXT      NULL);''')
    conn.commit()
    with open(file_name,'r') as f:
        data = json.load(f)
        for line in data['data']:
            index+=1
            sql = "insert into %s "%(table_name)+"(idx,date,Tag,URL,Title) values('%s','%s','%s','%s','%s')" % (line['Index'],line['Date'],line['Tag'],line['URL'],str(line['Title']))
            c.execute(sql)
            conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-ba295625ad7a> in <module>
#       2     table_name = 'SECTION' + str(i)
#       3     file_name = 'section'+str(i)+'.json'
# ----> 4     conn.execute('''CREATE TABLE %s'''%(table_name)+'''
#       5       (IDX      TEXT   NULL,
#       6        DATE            TEXT      NULL,
#
# OperationalError: table SECTION1 already exists

# %%
conn = sqlite3.connect("BBC_NEWS.db")
def qry(QUERRY):
    return pd.read_sql(QUERRY, conn)

pd.read_sql("SELECT * from SECTION1", conn)

# %%
DataFrame({"x":{"A":1,"B":3},
           "y":{"A":2,"B":4}})
